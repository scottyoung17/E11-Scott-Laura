# %% [markdown]
#    #### 1. Import the libraries needed for reading in and manipulating data

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

# %% [markdown]
# #### 2. Import data using pandas
#
# You can do this without downloading the data, or uploading to Google colab, by making a web request for the data using the link address for the data from the radwatch website.

# %%
local_string = r'C:\Users\scday\OneDrive\Documents\GitHub\E11-Scott-Laura\5minTest'
data = pd.read_csv(local_string)
display(data)
# Out:
#          Time  PM 1.0  PM 2.5  PM 10  Temperature    Gas   Humidity  \
# 0    16:13:21       1       2      3    23.923555  15544  16.210994
# 1    16:13:23       1       2      3    23.937812   5021  16.211696
# 2    16:13:24       0       1      2    23.969453   9966  16.188729
# 3    16:13:25       0       1      2    24.000508  14292  16.146121
# 4    16:13:26       0       1      2    24.029414  17669  16.103419
# ..        ...     ...     ...    ...          ...    ...        ...
# 247  16:18:16       0       1      1    24.386250  61659  15.572760
# 248  16:18:18       0       1      1    24.385078  61704  15.553176
# 249  16:18:19       0       1      1    24.383516  61568  15.562865
# 250  16:18:20       0       1      1    24.382734  61433  15.543302
# 251  16:18:21       0       1      1    24.383711  61659  15.538467
#
#         Pressure  Altitude  Unnamed: 9
# 0    1012.329937  7.662967         NaN
# 1    1012.328199  7.677450         NaN
# ...

# %% [markdown]
# ##### 2.a Take a look at what the data looks like
# The data has been loaded into a pandas DataFrame, a fancy multi-dimensional list, basically.

# %%
plt.plot(data['PM 1.0'])
plt.xlabel('CPS')
plt.ylabel('PM 1.0')                       # label the y-axis
plt.title("CPS vs PM 1.0")                                  # put a title!
plt.show()

# %%
plt.plot(data['PM 2.5'])
plt.xlabel('CPS')
plt.ylabel('PM 2.5')                       # label the y-axis
plt.title("CPS vs PM 2.5")                                  # put a title!
plt.show()

# %%
plt.plot(data['PM 10'])
plt.xlabel('CPS')
plt.ylabel('PM 10')                       # label the y-axis
plt.title("CPS vs PM 10")                                  # put a title!
plt.show()

# %%
plt.plot(data['Temperature'])
plt.xlabel('CPS')
plt.ylabel('Temperature')                       # label the y-axis
plt.title("CPS vs Temperature")                                  # put a title!
plt.show()

# %%
plt.plot(data['Gas'])
plt.xlabel('CPS')
plt.ylabel('Gas')                       # label the y-axis
plt.title("CPS vs Gas")                                  # put a title!
plt.show()

# %%
plt.plot(data['Humidity'])
plt.xlabel('CPS')
plt.ylabel('Humidity')                       # label the y-axis
plt.title("CPS vs Humidity")                                  # put a title!
plt.show()

# %%
plt.plot(data['Pressure'])
plt.xlabel('CPS')
plt.ylabel('Pressure')                       # label the y-axis
plt.title("CPS vs Pressure")                                  # put a title!
plt.show()

# %%
plt.plot(data['Altitude'])
plt.xlabel('CPS')
plt.ylabel('Altitude')                       # label the y-axis
plt.title("CPS vs Altitude")                                  # put a title!
plt.show()
